# %%
import pandas as pd

# %%
path='31个三通局5月过坝计划汇总.xlsx'

# %%
dd=pd.read_excel(path,header=None,sheet_name=None)
for sheet_name,e_df in dd.items():
    print(sheet_name,e_df)
# Out:
# day_0531           0              1
# 0   江海洋2016   92.00, 16.20
# 1     航万968  104.98, 16.23
# 2     灏泽001  105.00, 16.23
# 3    长兴1668  129.98, 16.26
# 4     镔港968  108.00, 17.25
# ..      ...            ...
# 57     富发88   93.82, 16.20
# 58   弘茂6666      80.0,14.0
# 59  豫周江河610      80.0，14.0
# 60    航发898   80.00, 13.63
# 61      鹏杰5   80.00, 13.63
#
# [62 rows x 2 columns]
# day_0530            0              1
# 0      荣江019  110.00, 19.25
# 1   新长江06072  110.00, 19.24
# 2   豫信货16899      99.0，16.0
# 3      洋河998   99.80, 16.25
# 4        渝扬2  106.00, 17.28
# 5       圣通19  110.00, 19.25
# 6     宏声3105   87.00, 14.83
# 7     金甲5198     105.0，16.0
# 8   豫信货15278   79.60, 13.60
# 9   豫信货17118     105.0，17.0
# 10     江运916  110.00, 19.20
# 11    旺洲2001  110.00, 19.28
# 12     镔港817  109.70, 16.24
# 13    龙昊2021     130.0，16.0
# 14       油源6   87.30, 13.23
# 15     秭归819   83.00, 13.84
# 16     天畅906   84.90, 14.03
# 17    曙光9888   90.45, 14.83
# 18  豫信货16986      79.0，13.0
# ...
